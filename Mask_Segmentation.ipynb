# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidMartinez16/Mask-Detection-and-Segmentation/blob/master/Mask_Segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import libraries

# %%
import os
import sys
import json
import numpy as np
import time
from PIL import Image, ImageDraw
import skimage.draw
import random

# %%
# !git clone https://github.com/DavidReveloLuna/MaskRCNN_Video.git
# Out:
# Cloning into 'MaskRCNN_Video'...
# remote: Enumerating objects: 115, done.
# remote: Counting objects: 100% (115/115), done.
# remote: Compressing objects: 100% (105/105), done.
# remote: Total 115 (delta 41), reused 59 (delta 8), pack-reused 0
# Receiving objects: 100% (115/115), 48.60 MiB | 21.59 MiB/s, done.
# Resolving deltas: 100% (41/41), done.

# %%
cd MaskRCNN_Video/
# Out:
# /content/MaskRCNN_Video

# %%
# !python setup.py install
# Out:
# WARNING:root:Fail load requirements file, so using default ones.
# running install
# running bdist_egg
# running egg_info
# creating mask_rcnn.egg-info
# writing mask_rcnn.egg-info/PKG-INFO
# writing dependency_links to mask_rcnn.egg-info/dependency_links.txt
# writing top-level names to mask_rcnn.egg-info/top_level.txt
# writing manifest file 'mask_rcnn.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching 'requirements.txt'
# writing manifest file 'mask_rcnn.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/mrcnn
# copying mrcnn/parallel_model.py -> build/lib/mrcnn
# copying mrcnn/visualize.py -> build/lib/mrcnn
# copying mrcnn/config.py -> build/lib/mrcnn
# copying mrcnn/utils.py -> build/lib/mrcnn
# copying mrcnn/__init__.py -> build/lib/mrcnn
# copying mrcnn/model.py -> build/lib/mrcnn
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/mrcnn
# copying build/lib/mrcnn/parallel_model.py -> build/bdist.linux-x86_64/egg/mrcnn
# copying build/lib/mrcnn/visualize.py -> build/bdist.linux-x86_64/egg/mrcnn
# copying build/lib/mrcnn/config.py -> build/bdist.linux-x86_64/egg/mrcnn
# copying build/lib/mrcnn/utils.py -> build/bdist.linux-x86_64/egg/mrcnn
# copying build/lib/mrcnn/__init__.py -> build/bdist.linux-x86_64/egg/mrcnn
# copying build/lib/mrcnn/model.py -> build/bdist.linux-x86_64/egg/mrcnn
# byte-compiling build/bdist.linux-x86_64/egg/mrcnn/parallel_model.py to parallel_model.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mrcnn/visualize.py to visualize.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mrcnn/config.py to config.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mrcnn/utils.py to utils.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mrcnn/__init__.py to __init__.cpython-36.pyc
# byte-compiling build/bdist.linux-x86_64/egg/mrcnn/model.py to model.cpython-36.pyc
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying mask_rcnn.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mask_rcnn.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mask_rcnn.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying mask_rcnn.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# creating dist
# creating 'dist/mask_rcnn-2.1-py3.6.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing mask_rcnn-2.1-py3.6.egg
# Copying mask_rcnn-2.1-py3.6.egg to /usr/local/lib/python3.6/dist-packages
# Adding mask-rcnn 2.1 to easy-install.pth file
#
# Installed /usr/local/lib/python3.6/dist-packages/mask_rcnn-2.1-py3.6.egg
# Processing dependencies for mask-rcnn==2.1
# Finished processing dependencies for mask-rcnn==2.1

# %%
ROOT_DIR = '/content/MaskRCNN_Video'
assert os.path.exists(ROOT_DIR), 'ROOT_DIR does not exist'

sys.path.append(ROOT_DIR) 

from mrcnn import visualize
from mrcnn.config import Config
from mrcnn import model as modellib, utils

# %% [markdown]
# # Download pretrained model

# %%
# Directory to save logs and trained model
MODEL_DIR = os.path.join(ROOT_DIR, "logs")

# Local path to trained weights file
COCO_MODEL_PATH = os.path.join(ROOT_DIR, "mask_rcnn_coco.h5")

# Download COCO trained weights from Releases if needed
if not os.path.exists(COCO_MODEL_PATH):
    utils.download_trained_weights(COCO_MODEL_PATH)
# Out:
# Downloading pretrained model to /content/MaskRCNN_Video/mask_rcnn_coco.h5 ...
# ... done downloading pretrained model!

# %%
class MaskConfig(Config):
    """Configuration for training on the mask  dataset.
    """
    # Give the configuration a recognizable name
    NAME = "mask"

    # Train on 1 GPU and 1 image per GPU. Batch size is 1 (GPUs * images/GPU).
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

    # Number of classes (including background)
    NUM_CLASSES = 1 + 1  # background + 1 (mask)

    # All of our training images are 512x512
    IMAGE_MIN_DIM = 512
    IMAGE_MAX_DIM = 512

    # You can experiment with this number to see if it improves training
    STEPS_PER_EPOCH = 500

    # This is how often validation is run. If you are using too much hard drive space
    # on saved models (in the MODEL_DIR), try making this value larger.
    VALIDATION_STEPS = 5
    
    # Matterport originally used resnet101, but I downsized to fit it on my graphics card
    BACKBONE = 'resnet50'

    # To be honest, I haven't taken the time to figure out what these do
    RPN_ANCHOR_SCALES = (8, 16, 32, 64, 128)
    TRAIN_ROIS_PER_IMAGE = 32
    MAX_GT_INSTANCES = 50 
    POST_NMS_ROIS_INFERENCE = 500 
    POST_NMS_ROIS_TRAINING = 1000 
    
config = MaskConfig()
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet50
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        100
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_CHANNEL_COUNT            3
# IMAGE_MAX_DIM                  512
# IMAGE_META_SIZE                14
# IMAGE_MIN_DIM                  512
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [512 512   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               50
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           mask
# NUM_CLASSES                    2
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        500
# POST_NMS_ROIS_TRAINING         1000
# PRE_NMS_LIMIT                  6000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (8, 16, 32, 64, 128)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                500
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               5
# WEIGHT_DECAY                   0.0001

# %% [markdown]
# # Define some functions

# %%
class MaskDataset(utils.Dataset):

    def load_cascos(self, dataset_dir, subset):
        """Load a subset of the Mask dataset.
        dataset_dir: Root directory of the dataset.
        subset: Subset to load: train or val
        """
        # Add classes. We have only one class to add.
        self.add_class("mask", 1, "mask")

        # Train or validation dataset?
        assert subset in ["train", "val"]
        dataset_dir = os.path.join(dataset_dir, subset)

        # Load annotations
        # VGG Image Annotator (up to version 1.6) saves each image in the form:
        # { 'filename': '28503151_5b5b7ec140_b.jpg',
        #   'regions': {
        #       '0': {
        #           'region_attributes': {},
        #           'shape_attributes': {
        #               'all_points_x': [...],
        #               'all_points_y': [...],
        #               'name': 'polygon'}},
        #       ... more regions ...
        #   },
        #   'size': 100202
        # }
        # We mostly care about the x and y coordinates of each region
        # Note: In VIA 2.0, regions was changed from a dict to a list.
        annotations = json.load(open(os.path.join(dataset_dir, "via_region_data.json")))
        annotations = list(annotations.values())  # don't need the dict keys

        # The VIA tool saves images in the JSON even if they don't have any
        # annotations. Skip unannotated images.
        annotations = [a for a in annotations if a['regions']]

        # Add images
        for a in annotations:
            # Get the x, y coordinaets of points of the polygons that make up
            # the outline of each object instance. These are stores in the
            # shape_attributes (see json format above)
            # The if condition is needed to support VIA versions 1.x and 2.x.
            if type(a['regions']) is dict:
                polygons = [r['shape_attributes'] for r in a['regions'].values()]
            else:
                polygons = [r['shape_attributes'] for r in a['regions']] 

            # load_mask() needs the image size to convert polygons to masks.
            # Unfortunately, VIA doesn't include it in JSON, so we must read
            # the image. This is only managable since the dataset is tiny.
            image_path = os.path.join(dataset_dir, a['filename'])
            image = skimage.io.imread(image_path)
            height, width = image.shape[:2]

            self.add_image(
                "mask",
                image_id=a['filename'],  # use file name as a unique image id
                path=image_path,
                width=width, height=height,
                polygons=polygons)

    def load_mask(self, image_id):
        """Generate instance masks for an image.
       Returns:
        masks: A bool array of shape [height, width, instance count] with
            one mask per instance.
        class_ids: a 1D array of class IDs of the instance masks.
        """
        # If not a casco dataset image, delegate to parent class.
        image_info = self.image_info[image_id]
        if image_info["source"] != "mask":
            return super(self.__class__, self).load_mask(image_id)

        # Convert polygons to a bitmap mask of shape
        # [height, width, instance_count]
        info = self.image_info[image_id]
        mask = np.zeros([info["height"], info["width"], len(info["polygons"])],
                        dtype=np.uint8)
        for i, p in enumerate(info["polygons"]):
            # Get indexes of pixels inside the polygon and set them to 1
            rr, cc = skimage.draw.polygon(p['all_points_y'], p['all_points_x'])
            mask[rr, cc, i] = 1

        # Return mask, and array of class IDs of each instance. Since we have
        # one class ID only, we return an array of 1s
        return mask.astype(np.bool), np.ones([mask.shape[-1]], dtype=np.int32)

    def image_reference(self, image_id):
        """Return the path of the image."""
        info = self.image_info[image_id]
        if info["source"] == "mask":
            return info["path"]
        else:
            super(self.__class__, self).image_reference(image_id)

# %% [markdown]
# # Model Building

# %%
dataset_train = MaskDataset()
dataset_train.load_cascos("/content/MaskRCNN_Video/maskim", "train")
dataset_train.prepare()

# Validation dataset
dataset_val = MaskDataset()
dataset_val.load_cascos("/content/MaskRCNN_Video/maskim", "val")
dataset_val.prepare()

# %%
# Create model in training mode
model = modellib.MaskRCNN(mode="training", config=config,
                          model_dir=MODEL_DIR)

# %%
# Which weights to start with?
init_with = "coco"  # imagenet, coco, or last

if init_with == "imagenet":
    model.load_weights(model.get_imagenet_weights(), by_name=True)
elif init_with == "coco":
    # Load weights trained on MS COCO, but skip layers that
    # are different due to the different number of classes
    # See README for instructions to download the COCO weights
    model.load_weights(COCO_MODEL_PATH, by_name=True,
                       exclude=["mrcnn_class_logits", "mrcnn_bbox_fc", 
                                "mrcnn_bbox", "mrcnn_mask"])
elif init_with == "last":
    # Load the last model you trained and continue training
    model.load_weights(model.find_last(), by_name=True)

# %% [markdown]
# # Display random samples

# %%
# Load and display random samples
dataset = dataset_train
image_ids = np.random.choice(dataset.image_ids, 5)
for image_id in image_ids:
    image = dataset.load_image(image_id)
    mask, class_ids = dataset.load_mask(image_id)
    visualize.display_top_masks(image, mask, class_ids, dataset.class_names)

# %%
from mrcnn.model import log
# Load random image and mask.
image_id = random.choice(dataset.image_ids)
image = dataset.load_image(image_id)
mask, class_ids = dataset.load_mask(image_id)
# Compute Bounding box
bbox = utils.extract_bboxes(mask)

# Display image and additional stats
print("image_id ", image_id, dataset.image_reference(image_id))
log("image", image)
log("mask", mask)
log("class_ids", class_ids)
log("bbox", bbox)
# Display image and instances
visualize.display_instances(image, bbox, mask, class_ids, dataset.class_names)
# Out:
# image_id  20 /content/MaskRCNN_Video/maskim/train/asian_mask32.jpg
# image                    shape: (256, 170, 3)         min:    6.00000  max:  255.00000  uint8
# mask                     shape: (256, 170, 1)         min:    0.00000  max:    1.00000  bool
# class_ids                shape: (1,)                  min:    1.00000  max:    1.00000  int32
# bbox                     shape: (1, 4)                min:   39.00000  max:  152.00000  int32

# %% [markdown]
# # Train the model

# %%
model.train(dataset_train, dataset_val, 
            learning_rate=0.001, 
            epochs=50, 
            layers='heads')
# Out:
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: /content/MaskRCNN_Video/logs/mask20200905T1956/mask_rcnn_mask_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# rpn_model              (Functional)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# Epoch 1/50
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/indexed_slices.py:432: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
#   2/500 [..............................] - ETA: 2:24 - batch: 0.5000 - size: 1.0000 - loss: 5.4250 - rpn_class_loss: 0.0206 - rpn_bbox_loss: 1.9123 - mrcnn_class_loss: 1.5831 - mrcnn_bbox_loss: 1.1620 - mrcnn_mask_loss: 0.7469  WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.1930s vs `on_train_batch_end` time: 0.3035s). Check your callbacks.
# 500/500 [==============================] - 129s 258ms/step - batch: 249.5000 - size: 1.0000 - loss: 1.0875 - rpn_class_loss: 0.0129 - rpn_bbox_loss: 0.5780 - mrcnn_class_loss: 0.0773 - mrcnn_bbox_loss: 0.2365 - mrcnn_mask_loss: 0.1829 - val_loss: 0.7349 - val_rpn_class_loss: 0.0050 - val_rpn_bbox_loss: 0.4261 - val_mrcnn_class_loss: 0.0242 - val_mrcnn_bbox_loss: 0.1378 - val_mrcnn_mask_loss: 0.1419
# Epoch 2/50
# 500/500 [==============================] - 112s 225ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.4525 - rpn_class_loss: 0.0070 - rpn_bbox_loss: 0.2298 - mrcnn_class_loss: 0.0477 - mrcnn_bbox_loss: 0.0641 - mrcnn_mask_loss: 0.1039 - val_loss: 0.8289 - val_rpn_class_loss: 0.0028 - val_rpn_bbox_loss: 0.5643 - val_mrcnn_class_loss: 0.0357 - val_mrcnn_bbox_loss: 0.1095 - val_mrcnn_mask_loss: 0.1166
# Epoch 3/50
# 500/500 [==============================] - 110s 220ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.3174 - rpn_class_loss: 0.0057 - rpn_bbox_loss: 0.1589 - mrcnn_class_loss: 0.0348 - mrcnn_bbox_loss: 0.0383 - mrcnn_mask_loss: 0.0797 - val_loss: 0.7144 - val_rpn_class_loss: 0.0031 - val_rpn_bbox_loss: 0.3848 - val_mrcnn_class_loss: 0.0660 - val_mrcnn_bbox_loss: 0.0895 - val_mrcnn_mask_loss: 0.1711
# Epoch 4/50
# 500/500 [==============================] - 111s 221ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.2282 - rpn_class_loss: 0.0042 - rpn_bbox_loss: 0.1029 - mrcnn_class_loss: 0.0268 - mrcnn_bbox_loss: 0.0260 - mrcnn_mask_loss: 0.0682 - val_loss: 0.7976 - val_rpn_class_loss: 0.0046 - val_rpn_bbox_loss: 0.4383 - val_mrcnn_class_loss: 0.0715 - val_mrcnn_bbox_loss: 0.1250 - val_mrcnn_mask_loss: 0.1582
# Epoch 5/50
# 500/500 [==============================] - 110s 220ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.2185 - rpn_class_loss: 0.0035 - rpn_bbox_loss: 0.1038 - mrcnn_class_loss: 0.0234 - mrcnn_bbox_loss: 0.0246 - mrcnn_mask_loss: 0.0632 - val_loss: 0.7723 - val_rpn_class_loss: 0.0032 - val_rpn_bbox_loss: 0.4883 - val_mrcnn_class_loss: 0.0431 - val_mrcnn_bbox_loss: 0.0909 - val_mrcnn_mask_loss: 0.1467
# Epoch 6/50
# 500/500 [==============================] - 109s 219ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.1961 - rpn_class_loss: 0.0031 - rpn_bbox_loss: 0.0896 - mrcnn_class_loss: 0.0233 - mrcnn_bbox_loss: 0.0207 - mrcnn_mask_loss: 0.0593 - val_loss: 0.4811 - val_rpn_class_loss: 0.0021 - val_rpn_bbox_loss: 0.2121 - val_mrcnn_class_loss: 0.0341 - val_mrcnn_bbox_loss: 0.0463 - val_mrcnn_mask_loss: 0.1865
# Epoch 7/50
# 500/500 [==============================] - 110s 221ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.1772 - rpn_class_loss: 0.0033 - rpn_bbox_loss: 0.0792 - mrcnn_class_loss: 0.0240 - mrcnn_bbox_loss: 0.0173 - mrcnn_mask_loss: 0.0534 - val_loss: 0.7951 - val_rpn_class_loss: 0.0029 - val_rpn_bbox_loss: 0.3718 - val_mrcnn_class_loss: 0.1087 - val_mrcnn_bbox_loss: 0.1414 - val_mrcnn_mask_loss: 0.1702
# Epoch 8/50
# 500/500 [==============================] - 110s 220ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.1448 - rpn_class_loss: 0.0026 - rpn_bbox_loss: 0.0585 - mrcnn_class_loss: 0.0163 - mrcnn_bbox_loss: 0.0157 - mrcnn_mask_loss: 0.0517 - val_loss: 0.8238 - val_rpn_class_loss: 0.0018 - val_rpn_bbox_loss: 0.5276 - val_mrcnn_class_loss: 0.0464 - val_mrcnn_bbox_loss: 0.0785 - val_mrcnn_mask_loss: 0.1696
# Epoch 9/50
# 500/500 [==============================] - 110s 220ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.1317 - rpn_class_loss: 0.0027 - rpn_bbox_loss: 0.0486 - mrcnn_class_loss: 0.0184 - mrcnn_bbox_loss: 0.0122 - mrcnn_mask_loss: 0.0499 - val_loss: 0.6830 - val_rpn_class_loss: 0.0041 - val_rpn_bbox_loss: 0.1780 - val_mrcnn_class_loss: 0.1561 - val_mrcnn_bbox_loss: 0.1153 - val_mrcnn_mask_loss: 0.2295
# Epoch 10/50
# 500/500 [==============================] - 110s 221ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.1436 - rpn_class_loss: 0.0025 - rpn_bbox_loss: 0.0578 - mrcnn_class_loss: 0.0213 - mrcnn_bbox_loss: 0.0143 - mrcnn_mask_loss: 0.0477 - val_loss: 1.1310 - val_rpn_class_loss: 0.0030 - val_rpn_bbox_loss: 0.7599 - val_mrcnn_class_loss: 0.0802 - val_mrcnn_bbox_loss: 0.0937 - val_mrcnn_mask_loss: 0.1941
# Epoch 11/50
# 500/500 [==============================] - 110s 221ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.1262 - rpn_class_loss: 0.0022 - rpn_bbox_loss: 0.0457 - mrcnn_class_loss: 0.0191 - mrcnn_bbox_loss: 0.0131 - mrcnn_mask_loss: 0.0460 - val_loss: 0.9111 - val_rpn_class_loss: 0.0013 - val_rpn_bbox_loss: 0.2855 - val_mrcnn_class_loss: 0.2473 - val_mrcnn_bbox_loss: 0.1850 - val_mrcnn_mask_loss: 0.1920
# Epoch 12/50
# 500/500 [==============================] - 111s 221ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.1190 - rpn_class_loss: 0.0022 - rpn_bbox_loss: 0.0405 - mrcnn_class_loss: 0.0184 - mrcnn_bbox_loss: 0.0126 - mrcnn_mask_loss: 0.0452 - val_loss: 0.7244 - val_rpn_class_loss: 0.0022 - val_rpn_bbox_loss: 0.4099 - val_mrcnn_class_loss: 0.0782 - val_mrcnn_bbox_loss: 0.0653 - val_mrcnn_mask_loss: 0.1688
# Epoch 13/50
# 500/500 [==============================] - 111s 222ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.1036 - rpn_class_loss: 0.0021 - rpn_bbox_loss: 0.0307 - mrcnn_class_loss: 0.0161 - mrcnn_bbox_loss: 0.0109 - mrcnn_mask_loss: 0.0438 - val_loss: 0.3927 - val_rpn_class_loss: 9.5406e-04 - val_rpn_bbox_loss: 0.1698 - val_mrcnn_class_loss: 0.0155 - val_mrcnn_bbox_loss: 0.0302 - val_mrcnn_mask_loss: 0.1762
# Epoch 14/50
# 500/500 [==============================] - 111s 223ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.1278 - rpn_class_loss: 0.0018 - rpn_bbox_loss: 0.0484 - mrcnn_class_loss: 0.0204 - mrcnn_bbox_loss: 0.0125 - mrcnn_mask_loss: 0.0447 - val_loss: 1.0705 - val_rpn_class_loss: 0.0020 - val_rpn_bbox_loss: 0.5527 - val_mrcnn_class_loss: 0.1748 - val_mrcnn_bbox_loss: 0.1087 - val_mrcnn_mask_loss: 0.2323
# Epoch 15/50
# 500/500 [==============================] - 114s 229ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.0972 - rpn_class_loss: 0.0018 - rpn_bbox_loss: 0.0258 - mrcnn_class_loss: 0.0184 - mrcnn_bbox_loss: 0.0096 - mrcnn_mask_loss: 0.0417 - val_loss: 1.0667 - val_rpn_class_loss: 0.0023 - val_rpn_bbox_loss: 0.5021 - val_mrcnn_class_loss: 0.1351 - val_mrcnn_bbox_loss: 0.1789 - val_mrcnn_mask_loss: 0.2482
# Epoch 16/50
# 500/500 [==============================] - 113s 227ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.1075 - rpn_class_loss: 0.0019 - rpn_bbox_loss: 0.0362 - mrcnn_class_loss: 0.0153 - mrcnn_bbox_loss: 0.0126 - mrcnn_mask_loss: 0.0415 - val_loss: 0.9418 - val_rpn_class_loss: 7.3913e-04 - val_rpn_bbox_loss: 0.6356 - val_mrcnn_class_loss: 0.0195 - val_mrcnn_bbox_loss: 0.0953 - val_mrcnn_mask_loss: 0.1906
# Epoch 17/50
# 500/500 [==============================] - 111s 223ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.0957 - rpn_class_loss: 0.0017 - rpn_bbox_loss: 0.0272 - mrcnn_class_loss: 0.0164 - mrcnn_bbox_loss: 0.0100 - mrcnn_mask_loss: 0.0404 - val_loss: 0.8201 - val_rpn_class_loss: 0.0011 - val_rpn_bbox_loss: 0.5159 - val_mrcnn_class_loss: 0.0386 - val_mrcnn_bbox_loss: 0.0611 - val_mrcnn_mask_loss: 0.2034
# Epoch 18/50
# 500/500 [==============================] - 113s 226ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.1045 - rpn_class_loss: 0.0015 - rpn_bbox_loss: 0.0372 - mrcnn_class_loss: 0.0150 - mrcnn_bbox_loss: 0.0102 - mrcnn_mask_loss: 0.0405 - val_loss: 0.7547 - val_rpn_class_loss: 0.0036 - val_rpn_bbox_loss: 0.4510 - val_mrcnn_class_loss: 0.0711 - val_mrcnn_bbox_loss: 0.0645 - val_mrcnn_mask_loss: 0.1645
# Epoch 19/50
# 500/500 [==============================] - 119s 238ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.1106 - rpn_class_loss: 0.0016 - rpn_bbox_loss: 0.0376 - mrcnn_class_loss: 0.0175 - mrcnn_bbox_loss: 0.0118 - mrcnn_mask_loss: 0.0421 - val_loss: 0.9807 - val_rpn_class_loss: 0.0016 - val_rpn_bbox_loss: 0.6563 - val_mrcnn_class_loss: 0.0028 - val_mrcnn_bbox_loss: 0.1641 - val_mrcnn_mask_loss: 0.1559
# Epoch 20/50
# 500/500 [==============================] - 117s 234ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.1001 - rpn_class_loss: 0.0017 - rpn_bbox_loss: 0.0348 - mrcnn_class_loss: 0.0168 - mrcnn_bbox_loss: 0.0082 - mrcnn_mask_loss: 0.0388 - val_loss: 1.0172 - val_rpn_class_loss: 0.0015 - val_rpn_bbox_loss: 0.6258 - val_mrcnn_class_loss: 0.0417 - val_mrcnn_bbox_loss: 0.1155 - val_mrcnn_mask_loss: 0.2326
# Epoch 21/50
# 500/500 [==============================] - 120s 241ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.1005 - rpn_class_loss: 0.0015 - rpn_bbox_loss: 0.0339 - mrcnn_class_loss: 0.0168 - mrcnn_bbox_loss: 0.0107 - mrcnn_mask_loss: 0.0376 - val_loss: 1.0435 - val_rpn_class_loss: 0.0014 - val_rpn_bbox_loss: 0.6435 - val_mrcnn_class_loss: 0.1088 - val_mrcnn_bbox_loss: 0.1134 - val_mrcnn_mask_loss: 0.1764
# Epoch 22/50
# 500/500 [==============================] - 121s 242ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.0910 - rpn_class_loss: 0.0016 - rpn_bbox_loss: 0.0273 - mrcnn_class_loss: 0.0176 - mrcnn_bbox_loss: 0.0080 - mrcnn_mask_loss: 0.0366 - val_loss: 0.7811 - val_rpn_class_loss: 0.0011 - val_rpn_bbox_loss: 0.3844 - val_mrcnn_class_loss: 0.1146 - val_mrcnn_bbox_loss: 0.1189 - val_mrcnn_mask_loss: 0.1622
# Epoch 23/50
# 500/500 [==============================] - 122s 244ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.0838 - rpn_class_loss: 0.0013 - rpn_bbox_loss: 0.0213 - mrcnn_class_loss: 0.0154 - mrcnn_bbox_loss: 0.0082 - mrcnn_mask_loss: 0.0376 - val_loss: 1.1718 - val_rpn_class_loss: 4.5267e-04 - val_rpn_bbox_loss: 0.6054 - val_mrcnn_class_loss: 0.1730 - val_mrcnn_bbox_loss: 0.1557 - val_mrcnn_mask_loss: 0.2371
# Epoch 24/50
# 500/500 [==============================] - 122s 244ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.0854 - rpn_class_loss: 0.0013 - rpn_bbox_loss: 0.0228 - mrcnn_class_loss: 0.0163 - mrcnn_bbox_loss: 0.0089 - mrcnn_mask_loss: 0.0362 - val_loss: 0.7262 - val_rpn_class_loss: 0.0026 - val_rpn_bbox_loss: 0.4365 - val_mrcnn_class_loss: 0.0453 - val_mrcnn_bbox_loss: 0.0641 - val_mrcnn_mask_loss: 0.1776
# Epoch 25/50
# 500/500 [==============================] - 120s 241ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.0860 - rpn_class_loss: 0.0014 - rpn_bbox_loss: 0.0214 - mrcnn_class_loss: 0.0181 - mrcnn_bbox_loss: 0.0088 - mrcnn_mask_loss: 0.0363 - val_loss: 0.5537 - val_rpn_class_loss: 5.7361e-04 - val_rpn_bbox_loss: 0.1990 - val_mrcnn_class_loss: 0.0057 - val_mrcnn_bbox_loss: 0.1111 - val_mrcnn_mask_loss: 0.2374
# Epoch 26/50
# 500/500 [==============================] - 120s 241ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.1038 - rpn_class_loss: 0.0013 - rpn_bbox_loss: 0.0367 - mrcnn_class_loss: 0.0170 - mrcnn_bbox_loss: 0.0107 - mrcnn_mask_loss: 0.0381 - val_loss: 0.8436 - val_rpn_class_loss: 0.0014 - val_rpn_bbox_loss: 0.4329 - val_mrcnn_class_loss: 0.0491 - val_mrcnn_bbox_loss: 0.1316 - val_mrcnn_mask_loss: 0.2285
# Epoch 27/50
# 500/500 [==============================] - 121s 242ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.0920 - rpn_class_loss: 0.0012 - rpn_bbox_loss: 0.0287 - mrcnn_class_loss: 0.0137 - mrcnn_bbox_loss: 0.0113 - mrcnn_mask_loss: 0.0371 - val_loss: 1.0983 - val_rpn_class_loss: 0.0015 - val_rpn_bbox_loss: 0.6962 - val_mrcnn_class_loss: 0.0743 - val_mrcnn_bbox_loss: 0.0792 - val_mrcnn_mask_loss: 0.2471
# Epoch 28/50
# 500/500 [==============================] - 123s 246ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.0747 - rpn_class_loss: 0.0011 - rpn_bbox_loss: 0.0147 - mrcnn_class_loss: 0.0145 - mrcnn_bbox_loss: 0.0081 - mrcnn_mask_loss: 0.0362 - val_loss: 0.9494 - val_rpn_class_loss: 0.0014 - val_rpn_bbox_loss: 0.5038 - val_mrcnn_class_loss: 0.1247 - val_mrcnn_bbox_loss: 0.0929 - val_mrcnn_mask_loss: 0.2266
# Epoch 29/50
# 500/500 [==============================] - 124s 247ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.0682 - rpn_class_loss: 0.0014 - rpn_bbox_loss: 0.0142 - mrcnn_class_loss: 0.0109 - mrcnn_bbox_loss: 0.0070 - mrcnn_mask_loss: 0.0347 - val_loss: 0.8478 - val_rpn_class_loss: 0.0016 - val_rpn_bbox_loss: 0.4601 - val_mrcnn_class_loss: 0.0838 - val_mrcnn_bbox_loss: 0.1081 - val_mrcnn_mask_loss: 0.1942
# Epoch 30/50
# 500/500 [==============================] - 122s 244ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.0703 - rpn_class_loss: 0.0010 - rpn_bbox_loss: 0.0152 - mrcnn_class_loss: 0.0138 - mrcnn_bbox_loss: 0.0067 - mrcnn_mask_loss: 0.0335 - val_loss: 0.7429 - val_rpn_class_loss: 3.5199e-04 - val_rpn_bbox_loss: 0.4369 - val_mrcnn_class_loss: 0.0125 - val_mrcnn_bbox_loss: 0.0684 - val_mrcnn_mask_loss: 0.2247
# Epoch 31/50
# 500/500 [==============================] - 121s 243ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.0689 - rpn_class_loss: 0.0011 - rpn_bbox_loss: 0.0166 - mrcnn_class_loss: 0.0110 - mrcnn_bbox_loss: 0.0070 - mrcnn_mask_loss: 0.0331 - val_loss: 0.9514 - val_rpn_class_loss: 0.0020 - val_rpn_bbox_loss: 0.5437 - val_mrcnn_class_loss: 0.0994 - val_mrcnn_bbox_loss: 0.0652 - val_mrcnn_mask_loss: 0.2410
# Epoch 32/50
# 500/500 [==============================] - 122s 244ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.0779 - rpn_class_loss: 8.8179e-04 - rpn_bbox_loss: 0.0182 - mrcnn_class_loss: 0.0168 - mrcnn_bbox_loss: 0.0081 - mrcnn_mask_loss: 0.0339 - val_loss: 0.9930 - val_rpn_class_loss: 7.5412e-04 - val_rpn_bbox_loss: 0.6461 - val_mrcnn_class_loss: 0.0334 - val_mrcnn_bbox_loss: 0.0887 - val_mrcnn_mask_loss: 0.2240
# Epoch 33/50
# 500/500 [==============================] - 121s 241ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.0793 - rpn_class_loss: 9.0852e-04 - rpn_bbox_loss: 0.0231 - mrcnn_class_loss: 0.0135 - mrcnn_bbox_loss: 0.0077 - mrcnn_mask_loss: 0.0340 - val_loss: 1.1547 - val_rpn_class_loss: 0.0020 - val_rpn_bbox_loss: 0.7547 - val_mrcnn_class_loss: 0.0877 - val_mrcnn_bbox_loss: 0.1090 - val_mrcnn_mask_loss: 0.2014
# Epoch 34/50
# 500/500 [==============================] - 117s 234ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.0753 - rpn_class_loss: 9.0320e-04 - rpn_bbox_loss: 0.0199 - mrcnn_class_loss: 0.0134 - mrcnn_bbox_loss: 0.0075 - mrcnn_mask_loss: 0.0337 - val_loss: 0.8597 - val_rpn_class_loss: 0.0025 - val_rpn_bbox_loss: 0.5692 - val_mrcnn_class_loss: 0.0245 - val_mrcnn_bbox_loss: 0.0563 - val_mrcnn_mask_loss: 0.2071
# Epoch 35/50
# 500/500 [==============================] - 123s 246ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.0712 - rpn_class_loss: 0.0011 - rpn_bbox_loss: 0.0193 - mrcnn_class_loss: 0.0116 - mrcnn_bbox_loss: 0.0063 - mrcnn_mask_loss: 0.0329 - val_loss: 0.7059 - val_rpn_class_loss: 0.0013 - val_rpn_bbox_loss: 0.2722 - val_mrcnn_class_loss: 0.1002 - val_mrcnn_bbox_loss: 0.1242 - val_mrcnn_mask_loss: 0.2081
# Epoch 36/50
# 500/500 [==============================] - 120s 241ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.0747 - rpn_class_loss: 8.5178e-04 - rpn_bbox_loss: 0.0214 - mrcnn_class_loss: 0.0094 - mrcnn_bbox_loss: 0.0088 - mrcnn_mask_loss: 0.0341 - val_loss: 1.0813 - val_rpn_class_loss: 9.5988e-04 - val_rpn_bbox_loss: 0.7557 - val_mrcnn_class_loss: 0.0398 - val_mrcnn_bbox_loss: 0.1037 - val_mrcnn_mask_loss: 0.1811
# Epoch 37/50
# 500/500 [==============================] - 120s 240ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.0729 - rpn_class_loss: 9.6603e-04 - rpn_bbox_loss: 0.0202 - mrcnn_class_loss: 0.0106 - mrcnn_bbox_loss: 0.0081 - mrcnn_mask_loss: 0.0331 - val_loss: 1.2016 - val_rpn_class_loss: 0.0020 - val_rpn_bbox_loss: 0.6488 - val_mrcnn_class_loss: 0.1479 - val_mrcnn_bbox_loss: 0.1530 - val_mrcnn_mask_loss: 0.2499
# Epoch 38/50
# 500/500 [==============================] - 121s 243ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.0781 - rpn_class_loss: 9.6696e-04 - rpn_bbox_loss: 0.0237 - mrcnn_class_loss: 0.0110 - mrcnn_bbox_loss: 0.0078 - mrcnn_mask_loss: 0.0347 - val_loss: 0.8389 - val_rpn_class_loss: 4.5145e-04 - val_rpn_bbox_loss: 0.4637 - val_mrcnn_class_loss: 0.0541 - val_mrcnn_bbox_loss: 0.0567 - val_mrcnn_mask_loss: 0.2639
# Epoch 39/50
# 500/500 [==============================] - 116s 232ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.0777 - rpn_class_loss: 8.0942e-04 - rpn_bbox_loss: 0.0237 - mrcnn_class_loss: 0.0123 - mrcnn_bbox_loss: 0.0076 - mrcnn_mask_loss: 0.0333 - val_loss: 0.9622 - val_rpn_class_loss: 0.0029 - val_rpn_bbox_loss: 0.3880 - val_mrcnn_class_loss: 0.1917 - val_mrcnn_bbox_loss: 0.1215 - val_mrcnn_mask_loss: 0.2581
# Epoch 40/50
# 500/500 [==============================] - 117s 235ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.0688 - rpn_class_loss: 9.4984e-04 - rpn_bbox_loss: 0.0145 - mrcnn_class_loss: 0.0118 - mrcnn_bbox_loss: 0.0076 - mrcnn_mask_loss: 0.0340 - val_loss: 1.3099 - val_rpn_class_loss: 0.0020 - val_rpn_bbox_loss: 0.7565 - val_mrcnn_class_loss: 0.0955 - val_mrcnn_bbox_loss: 0.1074 - val_mrcnn_mask_loss: 0.3485
# Epoch 41/50
# 500/500 [==============================] - 119s 239ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.0627 - rpn_class_loss: 8.8507e-04 - rpn_bbox_loss: 0.0163 - mrcnn_class_loss: 0.0071 - mrcnn_bbox_loss: 0.0063 - mrcnn_mask_loss: 0.0322 - val_loss: 0.8342 - val_rpn_class_loss: 0.0010 - val_rpn_bbox_loss: 0.4276 - val_mrcnn_class_loss: 0.0820 - val_mrcnn_bbox_loss: 0.0543 - val_mrcnn_mask_loss: 0.2692
# Epoch 42/50
# 500/500 [==============================] - 119s 239ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.0788 - rpn_class_loss: 9.7004e-04 - rpn_bbox_loss: 0.0253 - mrcnn_class_loss: 0.0114 - mrcnn_bbox_loss: 0.0081 - mrcnn_mask_loss: 0.0329 - val_loss: 0.7596 - val_rpn_class_loss: 8.0093e-04 - val_rpn_bbox_loss: 0.5017 - val_mrcnn_class_loss: 0.0062 - val_mrcnn_bbox_loss: 0.0582 - val_mrcnn_mask_loss: 0.1926
# Epoch 43/50
# 500/500 [==============================] - 120s 239ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.0767 - rpn_class_loss: 9.5621e-04 - rpn_bbox_loss: 0.0279 - mrcnn_class_loss: 0.0082 - mrcnn_bbox_loss: 0.0079 - mrcnn_mask_loss: 0.0317 - val_loss: 0.6800 - val_rpn_class_loss: 0.0013 - val_rpn_bbox_loss: 0.3923 - val_mrcnn_class_loss: 0.0313 - val_mrcnn_bbox_loss: 0.0441 - val_mrcnn_mask_loss: 0.2110
# Epoch 44/50
# 500/500 [==============================] - 121s 242ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.0777 - rpn_class_loss: 9.1580e-04 - rpn_bbox_loss: 0.0223 - mrcnn_class_loss: 0.0117 - mrcnn_bbox_loss: 0.0089 - mrcnn_mask_loss: 0.0338 - val_loss: 0.7248 - val_rpn_class_loss: 7.0195e-04 - val_rpn_bbox_loss: 0.3328 - val_mrcnn_class_loss: 0.0868 - val_mrcnn_bbox_loss: 0.0958 - val_mrcnn_mask_loss: 0.2087
# Epoch 45/50
# 500/500 [==============================] - 120s 241ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.0667 - rpn_class_loss: 7.6718e-04 - rpn_bbox_loss: 0.0162 - mrcnn_class_loss: 0.0107 - mrcnn_bbox_loss: 0.0072 - mrcnn_mask_loss: 0.0318 - val_loss: 0.9259 - val_rpn_class_loss: 5.7206e-04 - val_rpn_bbox_loss: 0.5119 - val_mrcnn_class_loss: 0.0610 - val_mrcnn_bbox_loss: 0.1053 - val_mrcnn_mask_loss: 0.2472
# Epoch 46/50
# 500/500 [==============================] - 126s 252ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.0755 - rpn_class_loss: 8.9885e-04 - rpn_bbox_loss: 0.0273 - mrcnn_class_loss: 0.0082 - mrcnn_bbox_loss: 0.0071 - mrcnn_mask_loss: 0.0319 - val_loss: 0.9953 - val_rpn_class_loss: 0.0013 - val_rpn_bbox_loss: 0.5310 - val_mrcnn_class_loss: 0.0778 - val_mrcnn_bbox_loss: 0.1233 - val_mrcnn_mask_loss: 0.2618
# Epoch 47/50
# 500/500 [==============================] - 124s 248ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.0752 - rpn_class_loss: 9.2367e-04 - rpn_bbox_loss: 0.0230 - mrcnn_class_loss: 0.0119 - mrcnn_bbox_loss: 0.0076 - mrcnn_mask_loss: 0.0318 - val_loss: 1.0359 - val_rpn_class_loss: 0.0014 - val_rpn_bbox_loss: 0.6699 - val_mrcnn_class_loss: 0.0277 - val_mrcnn_bbox_loss: 0.0781 - val_mrcnn_mask_loss: 0.2588
# Epoch 48/50
# 500/500 [==============================] - 118s 237ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.0588 - rpn_class_loss: 9.5554e-04 - rpn_bbox_loss: 0.0124 - mrcnn_class_loss: 0.0080 - mrcnn_bbox_loss: 0.0062 - mrcnn_mask_loss: 0.0312 - val_loss: 1.4435 - val_rpn_class_loss: 0.0011 - val_rpn_bbox_loss: 0.8601 - val_mrcnn_class_loss: 0.0645 - val_mrcnn_bbox_loss: 0.1289 - val_mrcnn_mask_loss: 0.3888
# Epoch 49/50
# 500/500 [==============================] - 118s 235ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.0680 - rpn_class_loss: 7.9597e-04 - rpn_bbox_loss: 0.0157 - mrcnn_class_loss: 0.0125 - mrcnn_bbox_loss: 0.0069 - mrcnn_mask_loss: 0.0321 - val_loss: 1.0015 - val_rpn_class_loss: 0.0022 - val_rpn_bbox_loss: 0.5114 - val_mrcnn_class_loss: 0.1001 - val_mrcnn_bbox_loss: 0.1404 - val_mrcnn_mask_loss: 0.2474
# Epoch 50/50
# 500/500 [==============================] - 127s 254ms/step - batch: 249.5000 - size: 1.0000 - loss: 0.0636 - rpn_class_loss: 6.9098e-04 - rpn_bbox_loss: 0.0168 - mrcnn_class_loss: 0.0100 - mrcnn_bbox_loss: 0.0061 - mrcnn_mask_loss: 0.0300 - val_loss: 0.9196 - val_rpn_class_loss: 9.2577e-04 - val_rpn_bbox_loss: 0.3383 - val_mrcnn_class_loss: 0.1252 - val_mrcnn_bbox_loss: 0.0779 - val_mrcnn_mask_loss: 0.3773

# %%
class InferenceConfig(MaskConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1
    #IMAGE_MIN_DIM = 512
    #IMAGE_MAX_DIM = 512
    #DETECTION_MIN_CONFIDENCE = 0.85
    

inference_config = InferenceConfig()

# %%
# Recreate the model in inference mode
model = modellib.MaskRCNN(mode="inference", config=inference_config,  model_dir=MODEL_DIR)

# %%
# Get path to saved weights
# Either set a specific path or find last trained weights
# model_path = os.path.join(ROOT_DIR, ".h5 file name here")
model_path = model.find_last()

# Load trained weights (fill in path to trained weights here)
assert model_path != "", "Provide path to trained weights"
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name=True)
# Out:
# Loading weights from  /content/MaskRCNN_Video/logs/mask20200905T1956/mask_rcnn_mask_0050.h5
# Re-starting from epoch 50

# %% [markdown]
# # Testing the model with the test images

# %%
import skimage
real_test_dir = '/content/MaskRCNN_Video/maskim/test/'
image_paths = []
for filename in os.listdir(real_test_dir):
    if os.path.splitext(filename)[1].lower() in ['.png', '.jpg', '.jpeg']:
        image_paths.append(os.path.join(real_test_dir, filename))

for image_path in image_paths:
    img = skimage.io.imread(image_path)
    img_arr = np.array(img)
    results = model.detect([img_arr], verbose=1)
    r = results[0]
    visualize.display_instances(img, r['rois'], r['masks'], r['class_ids'], 
                                dataset_val.class_names, r['scores'], figsize=(5,5))
# Out:
# Processing 1 images
# image                    shape: (1500, 1000, 3)       min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1500.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
# Processing 1 images
# image                    shape: (270, 210, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  512.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
# Processing 1 images
# image                    shape: (225, 225, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  512.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
# Processing 1 images
# image                    shape: (181, 256, 3)         min:    6.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -123.70000  max:  148.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  512.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
# Processing 1 images
# image                    shape: (230, 251, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -123.70000  max:  150.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  512.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
# Processing 1 images
# image                    shape: (530, 530, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -114.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  530.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
# Processing 1 images
# image                    shape: (256, 256, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  512.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
# Processing 1 images
# image                    shape: (667, 1000, 3)        min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max: 1000.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
# Processing 1 images
# image                    shape: (313, 249, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -123.70000  max:  143.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  512.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
# Processing 1 images
# image                    shape: (225, 225, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  512.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
# Processing 1 images
# image                    shape: (256, 256, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  512.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
# Processing 1 images
# image                    shape: (144, 256, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  512.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
#
# *** No instances to display ***
# Processing 1 images
# image                    shape: (800, 800, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -101.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  800.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
# Processing 1 images
# image                    shape: (273, 387, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  512.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
# Processing 1 images
# image                    shape: (171, 256, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 512, 512, 3)      min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 14)               min:    0.00000  max:  512.00000  float64
# anchors                  shape: (1, 65472, 4)         min:   -0.17712  max:    1.05188  float32
